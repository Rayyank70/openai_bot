# %%
import os
import openai

openai.api_key = os.getenv("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")

response = openai.Completion.create(
  model="text-davinci-003",
  prompt="You: What have you been up to?\nFriend: Watching old movies.\nYou: Did you watch anything interesting?\nFriend:",
  temperature=0.5,
  max_tokens=60,
  top_p=1.0,
  frequency_penalty=0.5,
  presence_penalty=0.0,
  stop=["You:"]
)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In [16], line 6
#       2 import openai
#       4 openai.api_key = os.getenv("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")
# ----> 6 response = openai.Completion.create(
#       7   model="text-davinci-003",
#       8   prompt="You: What have you been up to?\nFriend: Watching old movies.\nYou: Did you watch anything interesting?\nFriend:",
#       9   temperature=0.5,
#      10   max_tokens=60,
#      11   top_p=1.0,
#      12   frequency_penalty=0.5,
#      13   presence_penalty=0.0,
#      14   stop=["You:"]
#      15 )
#
# File /opt/conda/lib/python3.8/site-packages/openai/api_resources/completion.py:31, in Completion.create(cls, *args, **kwargs)
#      29 while True:
#      30     try:
# ---> 31         return super().create(*args, **kwargs)
#      32     except TryAgain as e:
#      33         if timeout is not None and time.time() > start + timeout:
#
# File /opt/conda/lib/python3.8/site-packages/openai/api_resources/abstract/engine_api_resource.py:92, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#      89 elif timeout == 0:
#      90     params["timeout"] = MAX_TIMEOUT
# ---> 92 requestor = api_requestor.APIRequestor(
#      93     api_key,
#      94     api_base=api_base,
#      95     api_type=api_type,
#      96     api_version=api_version,
#      97     organization=organization,
#      98 )
#      99 url = cls.class_url(engine, api_type, api_version)
#     100 response, _, api_key = requestor.request(
#     101     "post",
#     102     url,
#    (...)
#     106     request_id=request_id,
#     107 )
#
# File /opt/conda/lib/python3.8/site-packages/openai/api_requestor.py:85, in APIRequestor.__init__(self, key, api_base, api_type, api_version, organization)
#      76 def __init__(
#      77     self,
#      78     key=None,
#    (...)
#      82     organization=None,
#      83 ):
#      84     self.api_base = api_base or openai.api_base
# ---> 85     self.api_key = key or util.default_api_key()
#      86     self.api_type = (
#      87         ApiType.from_str(api_type)
#      88         if api_type
#      89         else ApiType.from_str(openai.api_type)
#      90     )
#      91     self.api_version = api_version or openai.api_version
#
# File /opt/conda/lib/python3.8/site-packages/openai/util.py:183, in default_api_key()
#     181     return openai.api_key
#     182 else:
# --> 183     raise openai.error.AuthenticationError(
#     184         "No API key provided. You can set your API key in code using 'openai.api_key = <API-KEY>', or you can set the environment variable OPENAI_API_KEY=<API-KEY>). If your API key is stored in a file, you can point the openai module at it with 'openai.api_key_path = <PATH>'. You can generate API keys in the OpenAI web interface. See https://onboard.openai.com for details, or email support@openai.com if you have any questions."
#     185     )
#
# AuthenticationError: No API key provided. You can set your API key in code using 'openai.api_key = <API-KEY>', or you can set the environment variable OPENAI_API_KEY=<API-KEY>). If your API key is stored in a file, you can point the openai module at it with 'openai.api_key_path = <PATH>'. You can generate API keys in the OpenAI web interface. See https://onboard.openai.com for details, or email support@openai.com if you have any questions.

# %%
# Out:
# Collecting autopep8==1.6.0
#   Downloading autopep8-1.6.0-py2.py3-none-any.whl (45 kB)
#      |████████████████████████████████| 45 kB 280 kB/s  eta 0:00:01
# Collecting certifi==2021.10.8
#   Downloading certifi-2021.10.8-py2.py3-none-any.whl (149 kB)
#      |████████████████████████████████| 149 kB 70.3 MB/s eta 0:00:01
# Collecting charset-normalizer==2.0.7
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Collecting click==8.0.3
#   Downloading click-8.0.3-py3-none-any.whl (97 kB)
#      |████████████████████████████████| 97 kB 430 kB/s  eta 0:00:01
# Collecting et-xmlfile==1.1.0
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Collecting Flask==2.0.2
#   Downloading Flask-2.0.2-py3-none-any.whl (95 kB)
#      |████████████████████████████████| 95 kB 345 kB/s  eta 0:00:01
# Collecting idna==3.3
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
#      |████████████████████████████████| 61 kB 594 kB/s  eta 0:00:01
# Collecting itsdangerous==2.0.1
#   Downloading itsdangerous-2.0.1-py3-none-any.whl (18 kB)
# Collecting Jinja2==3.0.2
#   Downloading Jinja2-3.0.2-py3-none-any.whl (133 kB)
#      |████████████████████████████████| 133 kB 86.6 MB/s eta 0:00:01
# Collecting MarkupSafe==2.0.1
#   Downloading MarkupSafe-2.0.1-cp38-cp38-manylinux2010_x86_64.whl (30 kB)
# Collecting numpy==1.21.3
#   Downloading numpy-1.21.3-cp38-cp38-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 66.1 MB/s eta 0:00:01
# Collecting openai==0.19.0
#   Downloading openai-0.19.0.tar.gz (42 kB)
#      |████████████████████████████████| 42 kB 83 kB/s s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting openpyxl==3.0.9
#   Downloading openpyxl-3.0.9-py2.py3-none-any.whl (242 kB)
#      |████████████████████████████████| 242 kB 94.7 MB/s eta 0:00:01
# Collecting pandas==1.3.4
#   Downloading pandas-1.3.4-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.5 MB)
#      |████████████████████████████████| 11.5 MB 26.8 MB/s eta 0:00:01
# Collecting pandas-stubs==1.2.0.35
#   Downloading pandas_stubs-1.2.0.35-py3-none-any.whl (159 kB)
#      |████████████████████████████████| 159 kB 63.2 MB/s eta 0:00:01
# Collecting pycodestyle==2.8.0
#   Downloading pycodestyle-2.8.0-py2.py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 49 kB/s s eta 0:00:01
# Requirement already satisfied: python-dateutil==2.8.2 in /opt/conda/lib/python3.8/site-packages (from -r openai-quickstart-python/requirements.txt (line 17)) (2.8.2)
# Collecting python-dotenv==0.19.2
#   Downloading python_dotenv-0.19.2-py2.py3-none-any.whl (17 kB)
# Collecting pytz==2021.3
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
#      |████████████████████████████████| 503 kB 72.2 MB/s eta 0:00:01
# Collecting requests==2.26.0
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 75 kB/s s eta 0:00:01
# Requirement already satisfied: six==1.16.0 in /opt/conda/lib/python3.8/site-packages (from -r openai-quickstart-python/requirements.txt (line 21)) (1.16.0)
# Requirement already satisfied: toml==0.10.2 in /opt/conda/lib/python3.8/site-packages (from -r openai-quickstart-python/requirements.txt (line 22)) (0.10.2)
# Requirement already satisfied: tqdm==4.62.3 in /opt/conda/lib/python3.8/site-packages (from -r openai-quickstart-python/requirements.txt (line 23)) (4.62.3)
# Requirement already satisfied: urllib3==1.26.7 in /opt/conda/lib/python3.8/site-packages (from -r openai-quickstart-python/requirements.txt (line 24)) (1.26.7)
# Collecting Werkzeug==2.0.2
#   Downloading Werkzeug-2.0.2-py3-none-any.whl (288 kB)
#      |████████████████████████████████| 288 kB 85.3 MB/s eta 0:00:01
# Building wheels for collected packages: openai
#   Building wheel for openai (PEP 517) ... done
#   Created wheel for openai: filename=openai-0.19.0-py3-none-any.whl size=53512 sha256=9d00dadc88d647496cc801a2985b1098f37d679b9446c54456966bca5979ba93
#   Stored in directory: /home/jovyan/.cache/pip/wheels/a0/1c/c6/e258dd9f51667f810902504b9bdeeeb4f2298f72effc65bc2c
# Successfully built openai
# Installing collected packages: pycodestyle, autopep8, certifi, charset-normalizer, click, et-xmlfile, itsdangerous, MarkupSafe, Jinja2, Werkzeug, Flask, idna, numpy, requests, openpyxl, pandas-stubs, pytz, pandas, openai, python-dotenv
#   Attempting uninstall: certifi
#     Found existing installation: certifi 2022.9.14
#     Uninstalling certifi-2022.9.14:
#       Successfully uninstalled certifi-2022.9.14
#   Attempting uninstall: charset-normalizer
#     Found existing installation: charset-normalizer 2.0.0
#     Uninstalling charset-normalizer-2.0.0:
#       Successfully uninstalled charset-normalizer-2.0.0
#   Attempting uninstall: click
#     Found existing installation: click 8.0.4
#     Uninstalling click-8.0.4:
#       Successfully uninstalled click-8.0.4
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.1.1
#     Uninstalling MarkupSafe-2.1.1:
#       Successfully uninstalled MarkupSafe-2.1.1
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 3.1.2
#     Uninstalling Jinja2-3.1.2:
#       Successfully uninstalled Jinja2-3.1.2
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 2.2.2
#     Uninstalling Werkzeug-2.2.2:
#       Successfully uninstalled Werkzeug-2.2.2
#   Attempting uninstall: idna
#     Found existing installation: idna 3.1
#     Uninstalling idna-3.1:
#       Successfully uninstalled idna-3.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.2.1
#     Uninstalling pytz-2022.2.1:
#       Successfully uninstalled pytz-2022.2.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.4.4
#     Uninstalling pandas-1.4.4:
#       Successfully uninstalled pandas-1.4.4
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# galpy 1.7.2 requires pytest, which is not installed.
# tensorboard 2.10.0 requires google-auth-oauthlib<0.5,>=0.4.1, but you'll have google-auth-oauthlib 0.5.3 which is incompatible.
# tensorboard 2.10.0 requires protobuf<3.20,>=3.9.2, but you'll have protobuf 4.21.6 which is incompatible.
# jupyterlab-server 2.15.1 requires jinja2>=3.0.3, but you'll have jinja2 3.0.2 which is incompatible.
# Successfully installed Flask-2.0.2 Jinja2-3.0.2 MarkupSafe-2.0.1 Werkzeug-2.0.2 autopep8-1.6.0 certifi-2021.10.8 charset-normalizer-2.0.7 click-8.0.3 et-xmlfile-1.1.0 idna-3.3 itsdangerous-2.0.1 numpy-1.21.3 openai-0.19.0 openpyxl-3.0.9 pandas-1.3.4 pandas-stubs-1.2.0.35 pycodestyle-2.8.0 python-dotenv-0.19.2 pytz-2021.3 requests-2.26.0
